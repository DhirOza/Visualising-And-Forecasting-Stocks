# %%
# !pip install yfinance --quiet
import yfinance as yf
# !pip install mplfinance --quiet
import mplfinance as mpf
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')
# Out:
#      |████████████████████████████████| 63 kB 1.7 MB/s
#      |████████████████████████████████| 6.4 MB 49.1 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
#      |████████████████████████████████| 70 kB 5.4 MB/s

# %%
reli=yf.Ticker("RELIANCE.NS").history('1y')
mpf.plot(reli, savefig='img.png')
mpf.plot(reli['2022-01-01':'2022-03-01'])

# %%
#Download data 
reli.to_csv('reli.csv')
data=pd.read_csv('reli.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          249 non-null    object
#  1   Open          249 non-null    float64
#  2   High          249 non-null    float64
#  3   Low           249 non-null    float64
#  4   Close         249 non-null    float64
#  5   Volume        249 non-null    int64
#  6   Dividends     249 non-null    float64
#  7   Stock Splits  249 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 15.7+ KB

# %%
data.Date=pd.to_datetime(data.Date)  # 
data=data.set_index('Date')
#mpf.plot(data)
mpf.plot(data['2022'],  type='line')

# %%
mpf.plot(data['2022'], type='candle')

# %%
mpf.plot(data['2022'], type='candle', volume=True)

# %%
mpf.plot(data['2021-09':'2022-2'], type='candle', 
         volume=True, mav=(10,5),title = 'Reliance',
        tight_layout=True, figratio=(16,9) )

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
mpf.plot(data['2021-10':'2022-2'], type='candle', volume=True, mav=(20,5), style='yahoo')
